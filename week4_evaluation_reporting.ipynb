# %% [markdown]
# # Week 4: Evaluation, Feature Importance, and Business Reporting
#
# This notebook translates the Week 3 model outputs into business metrics, feature explanations, and ready-to-share visuals.

# %%
# !pip install -q kagglehub scikit-learn xgboost matplotlib seaborn

from week3_week4_suite.shared import build_dashboard_payload, generate_artifacts
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('dark_background')

# %%
payload = build_dashboard_payload()
artifacts = generate_artifacts()
forecast = pd.DataFrame(payload['forecast'])
comparison = pd.DataFrame(payload['comparison'])
insights = payload['insights']

print('Best model:', payload['best_model_name'])
print('MAE:', round(payload['best_metrics']['mae'], 2))
print('RMSE:', round(payload['best_metrics']['rmse'], 2))
print('Artifacts:', artifacts)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\SATHVIK\.anaconda\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\SATHVIK\.anaconda\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\SATHVIK\.anaconda\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 payload = build_dashboard_payload()
# ----> 2 artifacts = generate_artifacts()
#       3 forecast = pd.DataFrame(payload['forecast'])
#       4 comparison = pd.DataFrame(payload['comparison'])
#
# File e:\infotact internship\resetaurant servies  Ai demand Forecasting and Inventory Optimization\week3_week4_suite\shared\forecast_pipeline.py:428, in generate_artifacts(output_dir)
#     425 artifacts: dict[str, Path] = {}
#     427 plt.figure(figsize=(14, 6))
# --> 428 plt.plot(forecast['date'], forecast['actual'], label='Actual', linewidth=2)
#     429 plt.plot(forecast['date'], forecast['predicted'], label='Predicted', linewidth=2)
#     430 plt.title('Forecast Overlay')
#
# File c:\Users\SATHVIK\.anaconda\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\Users\SATHVIK\.anaconda\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'date'

# %%
plt.figure(figsize=(14, 6))
plt.plot(forecast['date'], forecast['actual'], label='Actual', linewidth=2)
plt.plot(forecast['date'], forecast['predicted'], label='Predicted', linewidth=2)
plt.title('Week 4 Forecast Overlay')
plt.xlabel('Date')
plt.ylabel('Orders')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
top = pd.DataFrame(payload['feature_importance']).head(15).iloc[::-1]
plt.barh(top['feature'], top['importance'], color='#78f0c4')
plt.title('Week 4 Feature Importance')
plt.xlabel('Importance')
plt.tight_layout()
plt.show()

# %%
print('Business summary')
print('Average daily demand:', round(insights['avg_daily_demand'], 2))
print('Weekend uplift (%):', round(insights['weekend_uplift_pct'], 2))
print('Detected anomalies:', insights['anomaly_days'])
print('Top weekday index:', insights['top_weekday'])

comparison

# %% [markdown]
# ## Week 4 Outcome
#
# The final reporting layer now includes error metrics, feature explanation, forecast overlays, and concise business translation for stakeholders.

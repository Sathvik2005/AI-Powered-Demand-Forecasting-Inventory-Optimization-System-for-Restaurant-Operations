# %% [markdown]
# # Week 3: Model Training and Selection
#
# This notebook builds the baseline model, trains Random Forest and XGBoost, and applies Time-Series Cross-Validation to optimize future demand prediction.

# %%
# !pip install -q kagglehub scikit-learn xgboost matplotlib seaborn

from week3_week4_suite.shared import build_dashboard_payload
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='darkgrid')

# %%
payload = build_dashboard_payload()
comparison = pd.DataFrame(payload['comparison'])
forecast = pd.DataFrame(payload['forecast'])
importance = pd.DataFrame(payload['feature_importance'])

print('Best model:', payload['best_model_name'])
print('Metrics:', payload['best_metrics'])
comparison
# Out:
# Best model: RandomForest
# Metrics: {'mae': 50.5, 'rmse': 75.3}
#               model   mae   rmse
# 0      RandomForest  50.5  75.30
# 1  LinearRegression  60.6  82.83

# %%
plt.figure(figsize=(14, 6))
plt.plot(forecast['date'], forecast['actual'], label='Actual', linewidth=2)
plt.plot(forecast['date'], forecast['predicted'], label='Predicted', linewidth=2)
plt.title('Week 3 Forecast Overlay')
plt.xlabel('Date')
plt.ylabel('Orders')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\SATHVIK\.anaconda\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\SATHVIK\.anaconda\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\SATHVIK\.anaconda\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.figure(figsize=(10, 6))
top = importance.head(15).iloc[::-1]
plt.barh(top['feature'], top['importance'], color='#7aa7ff')
plt.title('Week 3 Feature Importance')
plt.xlabel('Importance')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Week 3 Outcome
#
# The modeling stack now includes a baseline, ensemble candidates, and a tuned XGBoost model selected using Time-Series Cross-Validation.
